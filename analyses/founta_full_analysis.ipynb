# %% [markdown]
# Inspired by kaggle.com/vpkprasanna/basic-text-cleaning-wordcloud-and-n-gram-analysis

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import rcParams
import re
from wordcloud import WordCloud
from collections import Counter
import csv
from matplotlib import rcParams
from nltk.corpus import stopwords
import nltk
from nltk.util import ngrams
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
stop = stopwords.words('english')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,plot_confusion_matrix
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import pandas as pd

data = pd.read_csv("/content/founta_dataset.csv", sep='\t', header=None)
data.head()
# Out:
#                                                    0        1  2
# 0  Beats by Dr. Dre urBeats Wired In-Ear Headphon...     spam  4
# 1  RT @Papapishu: Man it would fucking rule if we...  abusive  4
# 2  It is time to draw close to Him &#128591;&#127...   normal  4
# 3  if you notice me start to act different or dis...   normal  5
# 4  Forget unfollowers, I believe in growing. 7 ne...   normal  3

# %%
data.index.name = 'ID'
data.columns = ['text', 'label', 'votes']
data.head()
# Out:
#                                                  text    label  votes
# ID
# 0   Beats by Dr. Dre urBeats Wired In-Ear Headphon...     spam      4
# 1   RT @Papapishu: Man it would fucking rule if we...  abusive      4
# 2   It is time to draw close to Him &#128591;&#127...   normal      4
# 3   if you notice me start to act different or dis...   normal      5
# 4   Forget unfollowers, I believe in growing. 7 ne...   normal      3

# %%
data.label.value_counts()
# Out:
# normal     53851
# abusive    27150
# spam       14030
# hateful     4965
# Name: label, dtype: int64

# %%
rcParams['figure.figsize'] = 5,5
data.label.value_counts().plot(kind="bar")

# %%
tweets = data[data['label']=='hateful']
print(tweets.shape)

tweets_text_len = tweets['text'].str.len()
print("The maximum lenght of string in HATEFUL class is {} words".format(max(tweets_text_len)))
print("The minimum lenght of string in HATEFUL class is {} words".format(min(tweets_text_len)))
# Out:
# (4965, 3)
# The maximum lenght of string in HATEFUL class is 361 words
# The minimum lenght of string in HATEFUL class is 50 words

# %%
norm = data[data['label']=="normal"]
print(norm.shape)

tweets_text_len = tweets['text'].str.len()
print("The maximum lenght of string in HATEFUL class is {} words".format(max(tweets_text_len)))
print("The minimum lenght of string in HATEFUL class is {} words".format(min(tweets_text_len)))
# Out:
# (53851, 3)
# The maximum lenght of string in HATEFUL class is 361 words
# The minimum lenght of string in HATEFUL class is 50 words

# %%
#tokenization = splitting up a larger body of text into smaller lines, words 

def tokenize_and_stop_words(text):
    tokens = nltk.word_tokenize(text)
    # taken only words (not punctuation)
    token_words = [w for w in tokens if w.isalpha()]
    meaningful_words = [w for w in token_words if not w in stop]
    joined_words = ( " ".join(meaningful_words))
    return joined_words
tweets['text'] = tweets['text'].apply(tokenize_and_stop_words)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
def generate_word_cloud(text):
    wordcloud = WordCloud(
        width = 400,
        height = 400,
        background_color = 'white').generate(str(text))
    fig = plt.figure(
        figsize = (5, 5))
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()

tweets_text = tweets.text.values
generate_word_cloud(tweets_text)

# %%
def generate_word_cloud(text):
    wordcloud = WordCloud(
        width = 400,
        height = 400,
        background_color = 'white').generate(str(text))
    fig = plt.figure(
        figsize = (5, 5))
    plt.imshow(wordcloud, interpolation = 'bilinear')
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()

tweets_text = norm.text.values
generate_word_cloud(tweets_text)

# %%
set(data.text)
# Out:
# {"@KLUKLUXKUTIE No I understood what you were saying, and you're a fucking moron for it",
#  "Worst fucking week. I want to be on an island. Like 80% seriousness 20% laughing at the situations I've been in. https://t.co/V8IktMqSQ7",
#  'Just having a nice, relaxing bath... /I finaly made him to conquer his fear of water, after 75 shocks from him, i d… https://t.co/aseQuUp1CW',
#  '@SheerJenius And honestly, as a female breast admirer, because of how they look naturally and in bras, I call bras “breast trophy cases”.',
#  'Rick Wiles: Obama Is ‘Hiding From Arrest’ In French Polynesia For Stealing Elections And Surveilling Trump | https://t.co/ZKqdxyUAvB',
#  'You may be licking your emotional wounds today as you replay r... More for Leo https://t.co/o8CbBm8Xc3',
#  'How can the guests of the bridegroom mourn while he is with them? ...To know what is right and not do it is the worst cowardice.',
#  'Guy Verhofstadt: #Brexit a Tory cat-fight that got out of hand, a loss of time, a waste of energy, and stupidity https://t.co/doa3ATRtSg',
#  'Ultimate Itch Relief (And more!) Soap-Jewelweed, Coriander, Chamomile &amp; Goat Milk https://t.co/dBu9qAtXK2 https://t.co/M0hV4cdzU3',
#  '"Drafted" "World War III" "Things are getting bad" "Donald Trump is president" Me: Fuck it Im out #WWIII… https://t.co/CjFvTFHi8N',
#  'facts.. grape flavored shit is nasty https://t.co/gE29h2vDSk',
#  'A tiny part of me is happy for a few very dear friends who cherish their beloved Carolina. Cheers to you all. ...... https://t.co/xsjhBQ1zOr',
#  "@el_clough I'm driving back Monday afternoon if you want a lift! Got an interview in the morning then driving home",
#  "50% of people believe sex is the connecting of two people's souls through two people's bodies, as one. The other 50% are men.",
#  '@drukrishnan @RajPC1 @SethAMandel @EdWhelanEPPC No worries. Legal writing is hard when relaying facts. How many dif… https://t.co/JnvgmXXhKP',
#  '@SunScales @Blackmudpuppy That\'s how I read it, too. Glad I\'m not the only one. (Although "Half Your Frog" would be a great band name.)',
#  '@Mo_Mack @jensimmons The manipulation is strong, and the only emotions encouraged are guilt and fear.',
#  'Rigid Industries 30120 LED Halo Flashlight at 4 Wheel Parts - Save an instant $25 on the ... https://t.co/XiAJFZgCgu #Coupons #Shopping',
#  '#skinny dipping nude teens fucking with pakistani girl https://t.co/kMPF234HqH',
#  'I fucking died omf-- twin tails suits wang yo &#128514;&#128514; https://t.co/aM9n1pHPJ9',
#  "I've tweeted 2 politically related things today and could not regret it more if I tried. That's my quota for the year, back to wine &amp; sporps",
#  'Subscribe to UKURBANSFINEST YOUTUBE CHANNEL BEST IN MUSIC &amp; ENTERTAINMENT https://t.co/t95oc3gl6t',
#  'Fucked bareback by my apartment leasing agent https://t.co/QFaSLzb6e0',
#  'RT @EbonyDesire305: Let Goddess tease u into #Chastity stroke that pathetic cock in ya cage! https://t.co/A7JXamCoNI #EbonyGoddess…',
#  '@scridonliviu Suggest you research what actual sovereignty of a country means &amp; the difference between civil rights… https://t.co/t04m4QGKMy',
#  'RT @jaboukie: this dude bursts in wearing a fedora &amp; carrying a weird ass box says to me "i fucking hate EVERYONE" i say "yo same…',
#  '@Sipho_Sabo Right. Bc he spent a good portion of his soul having time trying to fight it, eat rats, &amp; brooding. ~Until Buffy~',
#  "@crimsonruari @matrioshkadog Except when they're not funny, they're just being mean selfish and drunk",
#  'Susan Rice Has Repeatedly Changed Her Story, Given Two Different Answers On Unmasking Trump… https://t.co/zjP93N53QV',
#  "meaning, I'm really funny and talented but no one ever pays attention to me so I never get recognition",
#  'Guy Live Tweets The Moments After His Roommate Murdered Her Boyfriend In Their Apartment https://t.co/DSUmTwIcFx',
#  "@OnticBot @guwop https://t.co/wh3EbZnHBd this is the funniest fucking song I've ever listened to",
#  'Latest @rogerkver steps: 1. Hire AstroTurf inc to blanket social media/Reddit 2. Release private DMs 3. Run smear campaigns on crappy media…',
#  'The best kind of friendships are when you both just amp the fuck out of each other to do stupid shit but still know ur boundaries',
#  'I liked a @YouTube video from @djvlad https://t.co/cSBy2zHX9J Mysonne on Future Poisoning Minds of Kids with Lyrics About Drug Culture',
#  '@FUDmuffin @RJSzczerba @realDonaldTrump @NBCNews Someone understands mutually exclusive sets! Hahahha',
#  '@CNNPolitics once u took office,U r responsible for everything that has happened on your watch,&amp;what will happen because of your ignorance',
#  'We are shopping for music producers to partner with for our movie project, we need Dance sound tracks. Its a Dance movie project',
#  'RT @SIRMANTHAALEONG: I wish I never even fucking knew u',
#  '@AshfordUnitedFC .....in front of a record league crowd for @AshfordUnitedFC of 457 - the best at Homelands since t… https://t.co/b3wLgPT18h',
#  '#heroacademy is ready to welcome its next group of superhero kids! #JYC2017 @GanderCitadel @SANLYouth @preachrman… https://t.co/EmUOtBaVnX',
#  "i haven't fucked any of them https://t.co/2n2DLH8XYc",
#  'Fucking While Man In The Shower https://t.co/2tuVRsGzRj',
#  '@Rev12Woman SoWarBroke OutIn1995 For1992.1993.1994.1995 2hit2017. AndAprylProseWasBorning 1/2Africans2RDAroririnv https://t.co/BELK70Nq8J',
#  "@WeeklyChris i feel so forgotten in this fandom :/ i know i shouldn't feel this way but i just don't feel like an important part of the fam",
#  'RT @angeIicslut: fuck i want these so bad https://t.co/Qe1qAyafSq',
#  '@JoelOsteen Hope your right Joel because it seems like time is running out, maybe your meant in the next life in heaven ?',
#  'This guy in high school use to call me "anorexis" because I was so skinny &amp; I hated it. But now I\'m "obesxis" and wouldn\'t mind goin back &#128514;',
#  '@lelappi all they care about on twitter/tumblr is fucking SHIPPING and they hate everyone that doesnt ship their ooc pairings',
#  'Latina Immigrant Fucked As Punishment https://t.co/qiVTmAjgnG',
#  '&#128149; Classic Noir Wrap, Halter Neck Vintage Highwaste bikini &#128089; For Hot Ladies&#128139; &#128073; https://t.co/IxN0udT5eZ ... by… https://t.co/5t6T4zIgMl',
#  "RT @ttwfoalexus: You've been out all night I don't know where you've been you're probably getting fucked you're probably giving head &#128533; #idf…",
#  "We don't have to know .......the supermarkets buy worldwide so everything is always in season&#129315;....... https://t.co/XFYO1mjzxR",
#  'there is no other anime site worse than this even the admins are dicks they even have a subscription lmao',
#  'My Twitter is worth $900.90!. Get your Twitter Value FREE at https://t.co/SlRnB5WNjt #free #tools #freefollowers',
#  '@Harry_Styles You changed my life so positively!! THANK U for saving me in all the ways a person can be saved! Thanks for everything&#127800;303,533',
#  '@AlajuwanBrown Done and done kid. Neighbor told me what make and model car hit it. Taking down their license plate next time I see them',
#  '@Shikarosez @TylerPreston20 Again, you have offered nothing but mistaken attribution due to paranoia. Insurance com… https://t.co/6FaWdBkmea',
#  'You should be embarrassed if this is true. @brianstelter @AC360 @jaketapper @jimsciutto https://t.co/cnnwRCMk1m',
#  "It's the final week for mine and @Emma_JaneMorton @brightonfringe show's crowdfunder! Thanks so much to those who've already donated... I'm",
#  'Worship is more of adoration PPSingers #ThanksgivingFriday with osasT via https://t.co/C8WtQ4QmA8',
#  "I've been drinking Pepsi for 37 years. I'm a Pepsi man through and through. fuck too disgusting coca cola [watches ad] Another Pepsi please",
#  '(1/5) I am excited that @FloGymnastics_ has all of a sudden rediscovered their interest in #NCAAMAG after months of no content about it.',
#  'RT @Y0B0YJ0HN: Dodgeball team tonight is about to be fucking OP.. &#128563; Duncan Falls, see you tonight! &#128520; @Newlex73 @aspicer33 @ClaYBillion @wil…',
#  'RT @tre_kelsey: You got me fucked up!!! https://t.co/CWhjS51bqH',
#  '3 New Facebook Updates, Features Businesses Should Take Advantage Of https://t.co/kq19eHpfk4 https://t.co/yFxYTh2IJX',
#  'I’m #TeamSerena in the @Chase Battle of the Paddle—nobody beats her backhand! Whose team are you on? https://t.co/XvyVEnjw7l',
#  'Music, once admitted to the soul, becomes a sort of spirit, and never dies."--Edward George Bulwer-Lytton #quote',
#  "just because I have tattoos doesn't make me a bad person. don't look at me like that. Lookin like the Grinch stole your dinner face ass hoe.",
#  '(1 of 2) “Even in our moments of deepest grief, in the moments when time stands still and life seems unfair…” #ElderClayton | #LDSConf',
#  '@Airtel_Ug would like to advise the public that it does not support or authorize the sale of any pre-registered or… https://t.co/FJSoPT8Wh8',
#  '2013dance Robin Thicke Give It 2 U (Moto Blanco Club Mix) (peaked at #21 in 2013) https://t.co/F0ilmKJLe3 #radio #dancemusic #clubmusic',
#  '@Tesco This has now been resolved by Tesco Extra Sprowston Norwich. Pack was returned for a full refund and new pack.',
#  'Our Uppermill High Street ice cream hut will be open tomorrow at 11.30am for the first time this… https://t.co/rT6HLhJrEn',
#  "@trebor12566 Yeah but ya know you're getting tired when Putin reading bedtime stories pop's into your head lol. Def… https://t.co/JzyQv4T5E5",
#  "im hella behind in a handful of manga and i can't remember what the last chapters i've read from them are fml",
#  "as grateful as i am for the life God blessed me with, He gave me the worst pair of lungs. i can't breathe for shit and it's getting so bad",
#  "Diversity Leaders' Voice Top story: Three Star Leadership | Wally Bock | Book R… https://t.co/hFV7vwXWdK, see more https://t.co/BAqtlfDYz5",
#  'The ordinary people now should start pelting stones at him. Then he will realise the pain of the army men there. https://t.co/C1YfKuigMr',
#  'Check out this satellite imagery of the strong spring storm impacting interior northern California. #cawx https://t.co/KosHygWoi1',
#  'i remember yrs ago a girl rping as rena hyuugu always saying "use soda" and it took me forever to get it was a joke based on rena\'s "uso da"',
#  'Lead Architect - Quantitative Analytics: Thomson Reuters Canada Limited (Toronto ON): "software is developed on… https://t.co/SwYI2Z3Qf9',
#  '#Dübendorf findom #nylon #instapicture upskirt teenie #adultsingles #curvy boobs fucking https://t.co/OuTOvg6IK6',
#  "You're still riding on the incoming waves of positive energy, ... More for Cancer https://t.co/lIeD44A4XU",
#  'use it, by him i mean him and scooter lfndkdnd, i just miss all the old stuff like this :( https://t.co/nTlmSvsizc',
#  'Modern Decor String Tassel Door Curtain with 3 Beads Window Room Divider White Q https://t.co/0FDlLWfPSB https://t.co/5URV7g7rib',
#  "Trying to read at least two novels a month at the moment and I'm debating if reading all the Alias volumes counts as one...",
#  "@RoundsR cus, Dems can't commit any felonies, it's a rule, and Blacks can't be racist. It's written some where.",
#  'Do not listen to those on the far-right of this discussion who are peddling what are clearly lies meant to mislead.',
#  'The Miz spent the last 8 months bringing prestige back to the Intercontinental Championship and they put it on the Pre-Show &#128545; #WrestleMania',
#  'A pumped up Jalik Smith of Susquehanna Twp. goes 10.88 in the finals of the 100m for the win #PanRam https://t.co/jObBmBJJrf',
#  "@casersatz @eLouSedator @Rory__Walker @CulturalGm6 I don't want to seek to change SJW minds, I want to ensure they… https://t.co/SmuLWKmrkP",
#  'THE BRUTAL SEAL MASSACRE STARTED TWO DAYS AGO, THIS IS A VICTIM OF ONE OF THE DERANGED ZOOSADISTS...clubbed to... https://t.co/6oWLOUwalK',
#  "@ResoluteQi — abilities. “That's pretty awesome. So, you just discovered your powers?” Scott was unaware that Danny was far from a mutant.",
#  'Nice crisp clean sour. Very refreshing. - Drinking a Grape Escape by @ofallonbrewery - https://t.co/VKDusavjoY #photo',
#  '@taylora98 We had such great stuff to watch as kids. I often feel sorry for the 90s generation they missed out on so much.',
#  '#TabPow Suit &amp; Tie iPad Mini Case - [Shockproof][Drop Protection][Heavy Duty] ... https://t.co/Mlto03PlDc 来自 @amazon',
#  'Larry, Curly and Moe impersonate college professors while Swinging the Alphabet https://t.co/KSjLfA1BVM',
#  '@ArloBenz &lt; fisted in your hair. We are like the energizer bunnies, we keep going and going, occasionally coming up… https://t.co/EHuPRkiZ5L',
#  'Reflexiones sobre #Youtube con @Korah_FF @teruriru_ t @isaacfcorrales en streaming ➡️https://t.co/mzxq0GQzpE… https://t.co/UFtf4covxF',
#  'Karma Kandara is the ultimate destination for an Easter getaway like no other, visit: https://t.co/lEwfOUIgO5 https://t.co/EuHhqw5Ome',
#  'Worcester Train 527 (6:20pm from S Station) departed S Station &amp; is operating 5-15 minutes late en route to Worcester #mbta',
#  'who else gets chisme when they go inside their local gas station&#128514; those ladies that work there are my best friends I swearrrrr',
#  'New Critapocalypse episode right here: Critapocalypse Podcast 62 - Kaka Kaijus https://t.co/XCXDvudAie on #SoundCloud',
#  "@emmy_the_great Thanks so much! Just working out exactly what I'll need and then will drop you a line in the next c… https://t.co/6YWJWNn6yn",
#  'RT @byebyedelilahhh: Oh you are really fucking around tonight, huh? https://t.co/TElNcuZeMg',
#  'MT @WayneBogda: Our rights were given by God secured by patriots and the torch passed to you.#1A #ReinInDC #ArticleV https://t.co/AoZuJCXD10',
#  'girls being fucked without knowledge https://t.co/Bj0tSL6osk',
#  '@Andy_Suth_UK @angelneptustar @trumpy675 @coffeecatspace @BorisJohnson @ShackProtein @realDonaldTrump Focus on the… https://t.co/CRJz43smNa',
#  'We are re-opening for the season! Join us Saturday, April 8 at Martin state airport for open cockpit! And then just say serving from',
#  "@elainovision @WiwiDenise @richmondbridge I'm not sure, but I plan to bring my camera and upload everything to the… https://t.co/eRCl524rOx",
#  'This is an urgent appeal to find Callum a bird plz recommend him to all friends, peers and coworkers the boy is lit as desperate as they get',
#  "@JERIs_world @tom_tmtaylor3 @billmaryy @ChristinaCNN @POTUS If Flynn's attorneys are trying to negotiate immunity,… https://t.co/WmL7StRjz0",
#  'Pretty clear nothing in the media can be believed. All they do is track down the narrative provided them by #dnc #sad',
#  '" I have no problem being called Benny! Just don\'t call my Ben 10. Or else You\'ll meet with a terrible fate. You cocky bitch.. " #Bot',
#  '&#128247; mattdaddairyo: “I don’t know about America, but in Australia, if you are next to a really good... https://t.co/AbE7Dl6lrp',
#  'Favstar_Bot: ticainuk ❤️❤️❤️❤️❤️ Your tweet has been liked by 5 people. https://t.co/mMLnQ9infc https://t.co/FJ60JHTi7E',
#  'Developers Are Trying To Port Android Wear To The Gear S3 https://t.co/ZcZtXPEXdE https://t.co/qW9ehmkk85',
#  '#ChaoticHouseParty RETURNS &#128293;&#128520; - LADIES FREE&#128483; - FREE EDIBLES &#128523;&#127849;&#127850; - MOON BOUNCE &#128559; @ STAR THEATER ⭐️ https://t.co/g4gngD8pER 3',
#  'Though the other 3 contestants were against him, JAKE pulled out a surprise Dome win! The eliminee is.... https://t.co/CDEbfmGLOF',
#  '@graphicscove @GlenLims Share me your details, Email us at jinihunk23@gmail.com or Skype: aglowid. I will be happy to help you on this.',
#  "I'm not sure how everyone can be so optimistic. We've been clueless. We ground these out last season that's why we were in top 4.",
#  "When Conley comes out it all falls apart... that's a FO problem that was the one glaring issue at the beginning of the season.",
#  "@BlizzHeroes I'm over your stupid game. If you're not planning on ever fixn it, pls ban my account so that I don't risk login in ever again.",
#  "Now I've started calling them out on it Pleased to see my younger siblings calling out bullshit when they see it, t… https://t.co/j5Hjj8VXiS",
#  "i'm on the train and this boy is staring at me so aggressively while brushing his waves i can't lmaooooo omg",
#  '@EkbMary @RepChrisStewart @NRDems @RepSteveIsrael @jaredpolis The four horses of the apocolypse and you wonder why… https://t.co/qObF3XgWbm',
#  '@OfficialTWA You know what I found? The hardcore division. While doing the cleaning. Sami Moxley was there.',
#  'Some really nice &#128525; #vintagecamper interiors at #pismosouth &#128149;#vintagetrailerrally &#127774; #sandiego… https://t.co/Mn8zaJ5SXt',
#  '@FrankLuntz @const_liberty1 @PrisonPlanet I trust him before I trust some fat liberal with a bed toupee like you',
#  '@AlexandriaVATES understand. condition of Cameron &amp; Prince are good. Other rds in city are horrible. (Seminary, Braddock as examples). 1/',
#  'Lovely little cove, time for some holiday painting @RossHighArt you would be proud! https://t.co/7plgldHgwT',
#  'RT @WorIdStarLaugh: "Don\'t fucking vape on the pizza" https://t.co/ECCof7FTX1',
#  'Listens to future while writing a paper: *changes font of commas from 12 to 14* https://t.co/kbmV1ebfxf',
#  'Caretaker manager Steve Agnew is eager to find the right balance between attack and defence for Middlesbrough after the club slipped seven …',
#  'Number crunching for the past day - 1 new follower and NO unfollowers. Stats via https://t.co/1epDaY6bPm',
#  "@twoqiy @toi139 Characters\u200b belongs to DC comics ..Tim Drake and Jason Todd.. it's not Japanese manga",
#  'More recent press review: https://t.co/PmTs1VXvJm (@GiornaleTurismo); https://t.co/fKmoUS8MZE (@milanofinanza); https://t.co/M6othyOSzc',
#  '@FakeArtCritic @billmaher I find the US media a frustrating &amp; shocking institution. Afraid to go out on the limb &amp;… https://t.co/sx4lAJVjP5',
#  'RT @NikoUgly: BRUH NOOOOOOOO WHO FUCKING DID THIS?????? LMAOOOOOOOOO https://t.co/9HJI2pDkDR',
#  'I hope you guys accept me in the fandom and that I make some good friends in this fandom❤️ #5YearswithEXO',
#  '@SuzanneKelleher @icntmx @IvankaTrump @KateBennett_DC I think by falling for fake news, fake exit polls, and believ… https://t.co/sbh1fpjaaQ',
#  'The U.S. Strikes in Syria: The U.S. military struck a Syrian airfield near Homs, the… https://t.co/wo1HQKcEKj',
#  'GBP/USD Falls As Construction PMI Misses Forecast And US Trade Deficit Narrows https://t.co/4mLAqMmN9l',
#  'Just discovered Virginia Jackson\'s "The poet as Poetess" in Cambridge Companion to c19 American Poetry (2011) and YES 10/10 so helpful',
#  '@RSPCA_official @DailyMirror its about time all breeders had licensing for proof of every dog they breed &amp; 6 month rspca checks.',
#  'wishing a happy birthday to @hannahzachritz. one of the strongest, most intelligent, and inspiring people I know. love ya ❤️',
#  "Poll is up for 1 hour : Who's dish looks the best yall ? &#128129; @J4L_Litework or @J4LJazMonroe &#127869; #j4lfam @J4LOrg #cookoff #allsfairinloveandwar &#128149;",
#  "RT @G7906_: Y'all be doing hella shit for people who ain't doing nothing for you pathetic!",
#  "I AM LIVIDDDDDDDDDDDD!!!!!!!!!!!!!! HOLY EFFIN' SHIT!!!!!!!!!!!!!!! I AM SO PISSED!!!!!!!!! OMGGGG!!!!! BRYCE, YOU FUCKING SHIT HEAD!!!!!",
#  'NCFC NEWS: RAte the players: What did you think of Norwich City’s performance in their 3-0 defeat at Huddersfield? https://t.co/OB1C11HQ2k',
#  '3 people followed me and one person unfollowed me // automatically checked by https://t.co/w2jcVWMZx0',
#  '@ITV @GaryBarlow @takethat @OfficialMarkO @HowardDonald I absolutely love @GaryBarlow @OfficialMarkO @HowardDonald… https://t.co/xabC3g50vB',
#  'Charlie Sheen On The View (the Start Is Painful To Watch) ↺RT❤️️ https://t.co/7E3y1tOCzL #twoandahalfmen #theview #charl',
#  '@MsJLaw Thank you and you are more than welcome! I really hope you enjoy it and I miss that sunny personality and smile! ❤',
#  'WHY WOULD SNYONE FAVORITE THIS LIT THO WHAT DID HE DO DID WE ALL WATCH THE SAME SHOW https://t.co/TxEgHzc5pl',
#  "Go where you are celebrated not tolerated. If they can't see the real value of you, it's time for a new start. #DTBYStillTheOne",
#  "@smokeyxtaboo @khromtx @theEmmaBrockway You're on the wrong side of the people who own 300 million weapons if you t… https://t.co/Anpiga48iD",
#  'Its april fools day so someone tell me this is all a fucking joke.',
#  'Facebook makes me roll my eyes every time bc of the redundant posts and twitter puros corajes. Lucy out.',
#  '@onHERTODOLIST fuck wrong with you?!!!?! lmfaoooo niggas got amnesia on a Sunday &#128514;&#128514;&#128514;&#128514;&#128514;',
#  "@brookellucas @Alex_Duerden15 Blaenavon don't come on until like 9:45 and Anteros are on at 8:45, u can make it",
#  'Sometimes I feel like Duche bag calls to the clinic are just tests because of how idiotic the people get.',
#  'The normal narwhal noticed and named while the nocturnal narwhal nodded and nodded. #normalnarwhal #nocturnalnarwhal',
#  'The bigger you get the easier of a target you become, should make it easier for the haters to Kiss My A$$ ;)',
#  "What's crazy is we literally came thru this bitch &amp; snatched what we wanted.&#128514;&#128514;&#128514;&#128514;&#128514;",
#  '28% of companies in #Deloitte survey reveal they would likely pursue an #IPO in the next year with market optimism. https://t.co/Lw7mco7N99',
#  "i'all give a bitch her props before i hate on her #FACTS! &#129318;&#127997;\u200d♀️.",
#  "@AceLoliBot I need my fucking cancer, this ain't working",
#  '@Crimson_Fair @Hot_Pose_69 Thank you. And hopping your having a great sunday..And thanks for sharing..a new fan..',
#  "RT @Sd_wts: They Ain't Fucking With Me Now Ima Make Em Feel Me &#129296;&#128526;&#128175;",
#  'Sony Playstation 3 Super Slim 500 GB Garnet Red Console w/ 11 Games GTA Black Op https://t.co/GTthK5u74O https://t.co/yVYTHKPFGA',
#  "@thinkprogress And the more time we all spend defending Rice is time that could have been spent uncovering Trump's… https://t.co/IV228FjFRQ",
#  'Awesome win last night for the Colorado Rockies baseball team! I miss home sometimes just watching them play!',
#  "@MikeLenowsky @eddievanhalen @Yousra_Shahy No fukkin way! My 1st show,Queen,1980. Then VH, tour. Best 2 shows I've… https://t.co/4jpqBVtjaa",
#  'Apple News goes from walled garden to ‘well-lit garden’ with third-party measurement https://t.co/KA6DUuy7jD',
#  'Pop into an #EE store and pre-order the Samsung Galaxy S8 and S8+ before 5pm on 18 April, and you’ll receive it 8 days before launch',
#  "Fuck it I'm going to pold dancing classes !!! https://t.co/y8Tz6M47PR",
#  'Sometimes you just need to slow down, remain calm, breathe, and simply let life happen. #ThursdayThoughts',
#  'Water In2 Wine has a show on 04/02/2017 at 10:30 AM @ Saginaw Wesleyan Church in Saginaw, MI... https://t.co/bOGV88uv78',
#  'We are looking for a buyer on 773 Commercial ST #Rockport #ME #realestate https://t.co/4HikRX5CzL https://t.co/BlfnPoByrx',
#  'Count your fucking tanrantanrantanran bleeeeessingsssssssssss',
#  'Volkswagen marketing director admits: battery kWh cost is already at 200 € - Push EVs https://t.co/PM0yfpc47z',
#  '2 people followed me and one person unfollowed me // automatically checked by https://t.co/vxtHnZPEeD',
#  'RT @colliscool: why does this video have me so fucked up https://t.co/wPRFMHJ5YY',
#  '04042017 21:00CET #Reading vs #Blackburn 69 percent of people have picked Reading What do you say? https://t.co/8U68Uy33pE',
#  '@nationalpost From that we can conclude a request take part in pre sentence report at time of warrant expiry or par… https://t.co/nuZoDRv6eI',
#  'Listen to the devotional about Stealing from a Rich God https://t.co/RIfjnKt31m #Bible https://t.co/bDasM6IJCs',
#  "Don't know how anyone can drink red bull or Coca-Cola unless they're mixed with some form of alcohol ha &#128567;",
#  'These politicians like Cruz and John Kasich has just stated that Donald Trump vs. Hillary Clinton wants completely open borders.',
#  '@Azrael1942 @TeleTransOne @_MarkingBad_ Collectively MEN unite under one flag and cover their backs with it just a… https://t.co/if7TxKuc0H',
#  'MY FUCKING REACTION TOO MY HEART SANK INTO MY ASS https://t.co/59cJBKGa1g',
#  'follow me on evanshalo (IG) its a multifandom account mainly based on ahs, the fosters, 13rw, and 5sos',
#  'John\'s absolutely right. Anyone who has ANY "rule" for their life based on religious grounds MUST be doing it for… https://t.co/2oesBubg1m',
#  "@jesserutherford did you realize that every fucking interview of you guys starts with sweater weather? 'Cause i did.",
#  'This brings the NO counts to 40. Coons is a likely NO too. May be slightly premature to say this, but I think we ha… https://t.co/bsfSRyeZ5a',
#  "I never thought I'd say this, but… Good job #TheresaMay; this was the right choice. #women https://t.co/Nmjbqbz1bP",
#  "@samanthamaiden #pmagenda IMF chief sends warning about Donald Trump and a 'race to the bottom' https://t.co/r2338KGo5H",
#  'Adriana Fucked By Guy In Pantyhose https://t.co/wFac7uSjbM',
#  'You gotta send him Good Morning &amp; Good Night texts even when you wake up &amp; go to sleep together &#128525;&#128536;&#128147;',
#  '+These 10 Photos of Yvonne Nelson In Casual Outfits Effortlessly Stole Hearts (photos) https://t.co/09ns78Q0Lr',
#  "Still upset I won't be able to see @theknocks next weekend in Austin. @MrJPatt @djbroc you guys are gonna kill it!",
#  'Tara game! May slut pa! Este slot https://t.co/tTODwV8WAF',
#  'RT @themurdermami: A fucking timeless BOP. https://t.co/dTtmsYUXo4',
#  '"Volkswagen to Pay 10 States Over Environmental Claims" by BILL VLASIC via NYT https://t.co/Qx1KWQD5eN #business… https://t.co/nsMQignIUV',
#  'Week today this great line-up #CruelExperience @WytchPycknyck #SPACECADET Balls to the wall garage psych! https://t.co/8bLrlOT9pY #Brighton',
#  'Argentina legalizes medical cannabis, creates research program with free access - The Cannabist: The… https://t.co/4TxGdMNVhr #Health US',
#  'If you want to keep your followers engaged and also save time throughout your day, RoundTeam is a great solution. https://t.co/8GJgpiHvOf',
#  '@crimsonelegance @PRETTYGIRLGG11 @FingersUpforDT There is no racism or sexism here- only the blind unhinged hatred coming from you. &#128580;',
#  'Ready for Summer? @Geobanny_Paula with 20% OFF Coolsculpting Fat Removal! Best rates/Best Results (2)',
#  "RT @Finnereaux: THE WORST!!! RT @cuntrocity: Fucking hate when I buy a train ticket and these fuckers don't check it",
#  'Heat 7: 5-1 #Lions! Riss ahead of Gomolski who gated. Masters third. @WolvesSpeedway 18 Lions 24 #speedway',
#  'ni semua normal ah every nasib in rs. one loyal one musibat. nnt cukup time both of it will switch. it become the opp.',
#  '&#127359;&#127345;1st time in industry One Click Watch #PP #Global Offers &amp; Indian Bazaar Rate Send Mail: pp@PolymerBazaar.com https://t.co/GTHKxmPT4T',
#  'RT @MrYitadee: My trust issues are really fucked up',
#  'https://t.co/0ZW6KzzGAL Are u a YouTuber looking to partner with a YouTube network? We accept everyone! Apply now… https://t.co/XZSl281jUZ',
#  "@OliWhiteTV @ollyofficial I HONESTLY CAN'T JABSHSH MY FAVOURITE TWO OLI/OLLY'S IM MEETING YOU AND I HAVE SEEN OLLY TWICE&#128514;",
#  'RT @colleenallen_: hmu if u want a bad bitch who shotguns mikes hard lemonades on school nights !!!!!! &#129304;&#127996;&#128548;&#128520;',
#  'PLAY #Bingo - SPEND GBP10 GET AND PLAY WITH GBP50 with #BGO - https://t.co/XYlcmbTWU0 https://t.co/8I9bfVAgaz',
#  'Just a little throw back cause I appreciate you and love you so much! Always know how to cheer me up @ashleighjxy https://t.co/O9Fcs2Obam',
#  '@JustKheemani @mabra_verified hey imbecile gtfo my page idiot',
#  "London News Search (Family win case over baby's flight delay compensation) 1 London - https://t.co/Ol61HtyoF1",
#  "@sandiegogirlie @Tony_Losoya Or just pretend you were thrashing around in withdrawals and it's sweat. Makes it feel grittier and raw.",
#  '#rockford_il FREESTYLE SKATING - Freestyle Skating Session @ Carlson Ice… https://t.co/kEU7Fvgw9Y #rockfordlink https://t.co/EE3lWyZG0G',
#  'Are you walking into a financial pit? #mortgagetips #finances https://t.co/6X705kQNYI https://t.co/TMn4GOQB2t',
#  'LAUNCH: "The world looks at you &amp; thinks you\'re an overnight success. But that\'s just not true." patrickc of strip… https://t.co/pB4fcf8ocp',
#  'HOW TO HACK HOTMAIL PASSWORD 2012 ADVANCED PASSWORD https://t.co/9E9rEuNgqW ANONYMOUS - MESSAGING TUTORIALS #2012 #Advanced #hack ANONYM',
#  'Home Features 5 Reasons why You Should set up a Reselling Web Hosting Business... - PC Tech Magazine https://t.co/EyzFquqt20',
#  'I played the Search the Waves mini game in Paradise Island 2, and my score was: 10 #ParadiseIsland2 #GameInsight https://t.co/JcspQtP8bU',
#  "It's been a while. #Orbiter #TheFair #FOOD @ Miami-Dade County Fair and Exposition https://t.co/wvypDz2Zjs",
#  "all those smiles and tears I store in here a multitude of sins won't let them out you and me were something #micropoetry #museinlove",
#  '"13 REASONS WHY" IS MAKING ME WISH I WENT TO A REAL FUCKING HIGHSCHOOL :(',
#  'GO SUBSCRIBE ON MATTHEW ESPINOSA YOUTUBE CHANNEL! turn on notifications, watch and like all videos. https://t.co/JKYTzhHUB4',
#  "@mcmoondog back in business? next week and i'm ok. no sticking this weekend. i still had hangover this morning.. what?",
#  '@OakTVOnline @Tweetwizzard retrieval of d so called disco &amp; genco back to d Nigerian states wil go a long way of getting an improved power',
#  'The last day of Capstones did not disappoint! Sad to see another year of projects behind us, but so proud of all th… https://t.co/8RBa3Y6rbf',
#  "@JestOneVote @Pyrotese @AdamPiersen @atwater_x @AISTQM @SAHinchcliffe NY has that. Hasn't changed a fucking thing. Absolutely USELESS.",
#  '#NowPlaying on Tabernacle Radio Chicago: Institutional Church of God in Christ - One More Day https://t.co/tjhlVBn2wC',
#  '@BennEllena @AmbientUXr @NathanLee @davrosz @TheIPA &gt; 40 odd are over 10k, and of those 13 are over 50k. But again, no specifics.',
#  'Vote for me to perform at #Nigeria Edition July 23rd 2017! https://t.co/jjbThttKov #Coast2Coast https://t.co/m4hAnQfRsT',
#  'It takes so little effort to put on a good show today that peo... More for Leo https://t.co/kb9DvHl4SS',
#  "#3Novices : South Korea's Park may be in larger cell than others, but lights out at 9 https://t.co/7xGnYuKIrx Dressed in the green jumpsui…",
#  'I cop this every time but also get parred since Aloe Vera also make wet wipes, so my boys refer to this as ass juice https://t.co/MND58nWZ12',
#  '#Photography #Joshua Tree National Park, California by Arka Mukhopadhyay https://t.co/GDBK33qmnA https://t.co/2CaRoJFZua',
#  "To all those people that think track isn't a contact sport-I just got hit with a metal baton in the 4x800",
#  'Gråbo Weather Data 08:00 AM Temperature:5.1oC Humidity:79 Wind Gust:0.0 m/s Dir: SSW Rain today: 0 mm This month:0… https://t.co/fg0gOfVJZt',
#  '@MMads and then you herd the fucking "swig-swam" some lord that insults then reply\'s.. Well..I guess..perspective paint\'s a mile',
#  'If the whole world was watching I’d still dance with you Drive highways and byways to be there with you Over and over the only truth',
#  'My friend mother is getting fucked and cumshot https://t.co/xzNs3mqKay',
#  "#FSU Florida State Seminoles Triblend T-Shirt, Toddler Boys' (2T-4T) https://t.co/x1vnzovXx6 #SportsRoadhouse",
#  'The realisation that there will always be disappointments,despite your best efforts,makes it easier to get back up.✊&#128170;',
#  "i cried over the fact that chyler and floriana are going to the glaad awards together,,, i'm so weak https://t.co/TtDACXbtpd",
#  '@Rambobiggs @Shanti__Ananda Where\'s the "Scream till I pass out" button? Damn I hate these bastards! Skin every one of them if I could!',
#  '.@ChrisMurphyCT: Trump Is Dragging Us Into Another War And No One Is Talking About It https://t.co/jSE0Nlci4J by #LOLGOP via @c0nvey',
#  'RT @markquillen: You must be an idiot Ima @ tf outta you https://t.co/2LtWW7ByPk',
#  'Rehearsal for #VictoryDay military parade in #Russia. TASS/Alamy Live News https://t.co/3X8G8Cvnnm https://t.co/tLupDBrBI9',
#  'Hundreds in Midtown, Union Square Protest US Airstrike in Syria | NBC New York https://t.co/g5CEzeAmQY via @nbcnewyork',
# ...
#  "@DeenerDrew @real_paul_allen @I_am_sick_witit @WhooFleuryScore Drew there's a shit ton of money to be made in this… https://t.co/qgbbEGruWH",
#  "It's time for @WWEEmberMoon Vs #NXTWomensChampion @WWEAsuka for the #NXTWomensTitle !!!!!!!!!!!!!!!!!!!!!!! #NXTTakeOverOrlando #NXTTakeOver",
#  'New With Tags Superdry Men New Athletes Entry tee T-shirt Size Large https://t.co/zf8ELCMF8u https://t.co/uFPWVvEazQ',
#  'Must read @NSCA SCJ issue on youth training! https://t.co/HrfOUp1lIU Great work from @Rhodri_S_Lloyd @AFaigenbaum @rihoward41 &amp; more!',
#  'Are we going to see a code-free future: https://t.co/hDTzZGPBIb #leanstartup via @brentsum https://t.co/g0qG2bmdRD',
#  'Health Select Committee inquiry into Rose Renton’s medicinal cannabis petition - have your say! https://t.co/tLffQ5fwOI',
#  'PS4 Technical Beta announced for GWENT: The Very Popular Witcher Card Game Is Moving Onto The… https://t.co/HwlmOhiElI #ps3 #ps4 #psvita',
#  "NETBET-Man Utd v Everton Bet £10 &amp; Get £40 in FREE bets,new customers,T&amp;C's apply use code GET40… https://t.co/jZOdhrl6Cl",
#  'RT @EastCoastSwag18: https://t.co/pg24d6Xmiz❗️❗️ VIEWER DISCRETION ADVISED❗️❗️❗️ fucking her mouth until she gags on PUKE ❗️❗️❗️',
#  'Walking With The Wounded support #veterans like Anam regain independence through employment. Read his story:… https://t.co/4UPnJv0BPf',
#  'RT @adoreaja: THEYRETOGETHER AGIN IM FUCKING YELLING https://t.co/1AGMco5M6s',
#  "It's European yet Asian. I miss Africa in this but the Asian touch just 'shouts' home #Mamaland #EasternAfrica",
#  '@TransfersXI yea we should keep him we have been very unlucky wit injuries lee is a big miss in midfield',
#  'Howdy @youbfit very interesting tweet about #fitness, can we talk about this https://t.co/0M4rsE1qy9',
#  "Can't wait for @YESLADBAND @YESLADLEWIS @YESLADSONNY @YESLADJAKE @YESLADCIAN @YESLADJOEL album to come out it will be lit so proud I❤️u guys",
#  'Gauge Fucked in the Ass By Friend https://t.co/xA0PKHcDpu',
#  'Twitter files lawsuit over US government attempt to identify users behind anti-Trump account https://t.co/4TYdX2TLwZ via @FoxNews',
#  '@laerwinUMD Best of luck to UMD in the Frozen Four finals! I can only imagine how exciting it is to be on your campus.',
#  'Senate filibuster: A nuisance or a treasured right -- depending on whose party is in power. https://t.co/dqmCPOdVZE… https://t.co/0RlLnI2XxF',
#  '@sftoonscreens The cartoon may be over but Capcom still supplies us with Megaman games, even toda... aw, shit.',
#  'thats what i want. eating chicken in the pool w my lover. hell yeah https://t.co/83frYkgiVn',
#  "The real story about #Syrian gas attacks no one is talking about. Were the victims Assad's political opponents? I might steal that idea.",
#  'RT @dontliedarling: @SINGDOLAN WTF WHY DO PPL FAV AND RT MY UGLY ASS',
#  'Today has been one bad ass day let me say is it beer thirty yet &#128526;&#128526;&#128526;&#128526;',
#  "@SenFranken Yes &amp; whatever happened to Sessions testifying to your committee about perjury? We didn't forget that didn't happen. @maudglib",
#  '@Simia_Pugno cant believe i got fucking pranked.........again!!!!!!!! fUCKING DARN!!!!!!',
#  '#cricket Umesh missing out was a surprise for us: Gambhir: Kolkata Knight Riders captain… https://t.co/oGJx9qzl31',
#  'Jack Richeson Shiva Oil Paintstik, Colonial Colors, Set of 6 https://t.co/ZZ5Rl2KeaN https://t.co/sYDwUGEjjZ',
#  '@PwC @CompassInc @CreativeGroup @MO_HOTELS are just a few of the recruiters here at the @GeorgetownSCS Spring 2017… https://t.co/N0wmjC6EFG',
#  '#EisenbergLawOffices,S.c Madison Law Firm explains who is at fault for your burn injuries. Read Blog: https://t.co/1UmFe7EKXQ',
#  'You cant tailor your situation in life but you can tailor make your attitudes to fit those situations. - Zig Ziglar',
#  'I wanna be fucked ! Go to the link- https://t.co/jql3TXOFuN https://t.co/bFww1vlZgh',
#  'Twitter users post the first pics and video of news events. Have they monetized this? No. Instead news orgs just become tireless vultures...',
#  'a bunch &#128079;&#127995; of fucking &#128079;&#127995; hypocrites &#128079;&#127995;&#128079;&#127995;&#128079;&#127995; https://t.co/6WjSL12fRT',
#  'Make #cash #online! Online money with a Hollywood story!: https://t.co/3IhSPd4vok Ways of #making #money online! https://t.co/tN1EofHcJL',
#  '@thelumineers @sustoisreal @officialkaleo Would love to hear "Falling" tonight in toon town!! #justincaseyouretakingrequests',
#  "#MLB #Baseball: Oakland A's L (42/44) #Athletics Button-Front Short Sleeved #Jersey by True Fan… https://t.co/tLnpaWOArR",
#  "1 A small reason I'm glad the GOP has opted for the nuclear option: journalists no longer have an excuse to use the… https://t.co/yTy53NpxN6",
#  'https://t.co/yxIrDlM1sz Yes the CGT should be collect by the seller and investigation should me done why govt let seller run away . #ncell',
#  'RT @amadeusfletch: "Did you take the picture yet? Jesus Christ hurry up and take the fucking picture." https://t.co/dWdJe2EZAh',
#  'Spouse @BessiePhD uses nettle leaf to manage her allergy symptoms - was able to give up the OTC Allegra... Do some… https://t.co/4ex0cG9v6h',
#  '@MeetThePress wondering what the media outlets like yourselves would be saying if Bush surveilled Obama? And there is no explanation. Liars.',
#  'Consider The Possibility That We Are Led By Idiots https://t.co/Zzftv0owkl',
#  '@MaryPena4 I feel bad though. If he really is a conservative I would like to try to give Pro Trump arguments and ma… https://t.co/tuoit49bug',
#  'The person I got on the work IT Help Desk is just quoting the email I sent them back at me. I give up.',
#  'RT @AKindAleWar: .@ComedyCentral FUCK OFF AND DIE!!! https://t.co/C6WNOogJrE',
#  'https://t.co/Zqf5hGhTbM #nowplaying Bing Crosby &amp; Grace Kelly - "True Love" in #1000oldies #slow #60s',
#  "Hello @Ahdeydurtune's 544 followers - I salute you. Let's keep doing the good work, the world need us. ➡️Get it&#127379;❓https://t.co/dNOQGY1N3f",
#  "@RendaBeltzer Ok... no I am not smarter than our Intel agencies... so, you agree with our Intel agencies on Trump's… https://t.co/ECI5t1ovTZ",
#  'How Slow Mobile Page Speeds Are Ruining Your Conversion Rates https://t.co/jCFSQeNo8X https://t.co/gwTcViL6eZ',
#  "Almost got a Switch. Almost. But then I had to set up a profile on Best Buy's site and that foiled my flawless plan.",
#  '$1 off 1 ARM &amp; Hammer Liquid Laundry Detergent via Couponing 4 You - HIGH VALUE COUPON ALERT!! $1 ... https://t.co/Zmlw9Xs3jY',
#  'cuz i just talked to my dad for like an hour about a bunch of stuff and one thing was that ADHD means memory problems and his mind was blown',
#  "I liked a @YouTube video https://t.co/tH8np8iZ4W Kendrick Lamar Celebrates Stretch Marks in New Song 'Humble' - The Breakfast Club",
#  'My visits: @meaanassriaahh @alwaysjulio_ @fw_chrxs @tesdnimneeuq_ @mookiieee__ Your visit: https://t.co/7HUDZ3kekH',
#  'Honestly love you so much Conor &amp; I wish I could get a cuddle off you ans you to tell me everything is going to be okay &#128148;&#128148;&#128148;&#128148; @ConorBrown27',
#  '2003 Harley-Davidson Touring 2003 Harley Davidson Road King Classic https://t.co/gF896CO8YE https://t.co/IpjMr17Vjv',
#  '@FightForHotep Last week Tillerson said a regime change in Syria was not the priority. Next day Assad gasses his own people angering world??',
#  'Joe Gibbs Racing Announces Kyle Benjamin will drive Four NASCAR XFINITY Series Races in 2017 https://t.co/wdXtdWK0wR',
#  'I lost it when I seen the dirty nigga pro club boxer briefs',
#  '@CNNPolitics Not going to report Obama admin. spying on candidate TrumpThis is why stopped watching you after the election &amp; I voted Hillary',
#  "RT @PositiveMinds__: Don't let idiots ruin your day.",
#  'Do you see where this is going on with all the fucking genders.',
#  'Ran into one of my grandads pals today Ive not seen since I was wee, I got"you\'re some height now Jordan" compared to what,a fucking smurf?&#129300;',
#  'RT @arsiniega_luis: Man I hate these fake ass people',
#  "Download @TrayThaPrince 'No Regrets' hosted by @FirestartaDJ using @MyMixtapez app #mymixtapez... https://t.co/W4RPi3lpXT",
#  'Why no Arsenal player wore captain’s armband after Koscielny’s injury against City Arsenal… https://t.co/mfQ4AgD0GR',
#  "It's time for a break. I'll be back with some &#128293;&#128293;. If you need anything contact me via email Huphbeats@gmail.com",
#  "Termites work 24 hours a day. Call us and we'll stop them, The Top Gun Way! 256-234-7375 https://t.co/ZD6tbCptg1 https://t.co/PPen9iAo49",
#  'Ansel Elgort, Regular Guy, Tried (And Failed) To Play It Cool Around Ryan Gosling https://t.co/eEMafWrwj3 https://t.co/5UFMlAuWCI',
#  'https://t.co/U0pNCd2exR #unsigned #talent #forum Axe reckons with a moral decision on #Billions. Our recap: … https://t.co/NgFefuCUFP',
#  '@TheSartists x @msRibane x @StandardBankZA making one day #Today at August House. https://t.co/WLu5scZ2xd',
#  'I’m #TeamStephen in the @Chase Battle of the Paddle—the MVP won’t disappoint. Whose team are you on? https://t.co/ypamZIvqpQ',
#  'We re-watched episode 1 of #TheHalcyon this week - but what was your favourite scene? Join us for ep2, Monday at 10pm! #SaveTheHalcyon',
#  'The National Service Scheme has released PIN Codes for prospective national service personnel for the 2017/2018... https://t.co/uo3OARhGBj',
#  'Stay hydrated at work! Finish a bottle of water before lunch EVERY DAY. https://t.co/QpPJIoPDS1 #HealthyLiving https://t.co/IiMmYm8Pm2',
#  'Blackburn and Wigan really headed to League One &#128567; but look at QPR and Birmingham City https://t.co/HxPm2RQpLM',
#  'This dog just messed up his cage&#128580; so glad it happened now before I was sleeping good then the middle of the night',
#  "@MattWalshBlog no a healthy marriage means that you can trust your spouse and that your spouse doesn't need you watching him to stay loyal.",
#  '6 Reasons Sleeping Without Clothes Is Good For Your Health https://t.co/Q4gUJos1zK https://t.co/Obg2IkjlUc',
#  "Just ordered my first thing online off Argos (moving boxes) &amp; they're coming Mon ☺ So that'll be like a xmas for me &#127876; Now gonna sort pc out.",
#  'Freelancer Wanted: Addressing Ageism: What You Need to Know to Land Freelance Writing Jobs…... https://t.co/JTpqH9wCz0',
#  'men being fucked with strapon dildo https://t.co/ScHjxPPZ5h',
#  "@FreeMemesKids worst edit I've ever seen what the fuck",
#  'These pass days have had me all kinds Fucked up...',
#  'I Swear Sometimes It Be Awkward As Hell Asking My Mom Things Pertaining To My Boyfriend',
#  '@Romcy001 It was a huge weekend of football! Check out all the highlights here -&gt; https://t.co/kOtzRsIa9V https://t.co/32kVST3hxM',
#  "LIKE THEY STILL BULLY EACH OTHER but they're friends tbh!!!!!! but in the beginning they legit don't like each other at all it's great",
#  "anyways on a serious note the reassurance is all in the process and it's something i knew before but now i understand",
#  'RT @WillyGCmas: Keep on Liking every one of my tweets but never RTing me you fucking annoying asshole.',
#  '@ProjetoooHelp @radiodisney WE GOTTA VOTE FASTER TO WIN CMON #OneDirection #YouKnowYouLoveThem #SteveAoki… https://t.co/xW5x7nftfS',
#  "acmc_clock_euro: #Ascendant / #MediumCoeli for Marseille, F for now (01h28m01s UT): 18°51'12.3'' #Capricorn (AC) / 15°23'12.0'' #Scorpio (M…",
#  "@_big_bad_bubba_ What a pitiful 'Mania this year. I even felt sorry for the 'Taker getting punked &amp; then retiring o… https://t.co/c6PAfeNlvB",
#  '@georgeszabo777 Just hearing, nuclear option, does not instill hope or a feeling of security. This is ignorant and… https://t.co/u0lTEuZvUK',
#  '.@darrenwalker "IT IS \'WE THE PEOPLE" WHO MAKE OUR NATION GREAT...who support the rural museums, the local theater… https://t.co/rwfgHTcrHi',
#  'Spectrobes Beyond The Portals game for Nintendo DS - New https://t.co/nwfvMWOHem https://t.co/NLxjFxYFDa',
#  'I Stay In Some Pussy I Been Getting Pussy Since 10/9/90 I Got The Bad Lightskin Joint She Stay Giving Me Brain @ 091-78-6901 I Stay In Pussy',
#  'Suicide sucks! Djeezz.. Nicola R.Z. 25 and leaving a loving husband and deeply caring family behind! We mourn with you all! #Australia',
#  '@ultraceecee He was such an asshole. I seriously had to take a break because I was so angry at the comments he was… https://t.co/RjnjeS1ilH',
#  'one person followed me and 2 people unfollowed me // automatically checked by https://t.co/RJwTZHAZZf',
#  'Win a cool iPad Air 2 &amp; The Code Breakers online biz guide. Thanks to @PeterPlbfranks and @appzthatrock: Enter now https://t.co/Q0ERj41rX2',
#  'Grote tieten sletterig cougar fucked door stud https://t.co/WzZaQZp2kT',
#  '⚾️&#127881;⚾️Oh Happy Day!! ⚾️&#127881;⚾️ Yadi a Cardinal for life! I could not be happier about this news!! ⚾️&#127881;⚾️&#127881;❤️⚾️❤️⚾️❤️⚾️❤️⚾️❤️⚾️❤️⚾️❤️',
#  'May your little one always have "happily ever afters" in their lives! #memorypreservationspecialists,... https://t.co/h6heamAwJ3',
#  "RealityJunkies Peta Jensen's Tits and Pussy Fucked https://t.co/fHSojUoD4W",
#  ...}

# %%
hateful = data[data['label']=="hateful"]
hateful['text'] = hateful['text'].apply(tokenize_and_stop_words)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
hate_speech = hateful['text'].values
generate_word_cloud(hate_speech)

# %%
hateful.head()
# Out:
#                                                   text    label  votes
# ID
# 21   Bad day Kyrgyzstan Suspect Petersburg metro bo...  hateful      2
# 34   I fucking moon cleared definition act war Now ...  hateful      3
# 37                   RT ynaoivw nah bitch hate u https  hateful      3
# 71       RT WaysThingsWork I fucking hate people https  hateful      3
# 106  You looked like complete pathetic idiot tonigh...  hateful      3

# %%
normal = data[data['label']=="normal"]
normal['text'] = normal['text'].apply(tokenize_and_stop_words)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
normaltxt = normal['text'].values
generate_word_cloud(normaltxt)

# %%
normal.head()
# Out:
#                                                  text   label  votes
# ID
# 2   It time draw close Him Father I draw near alwa...  normal      4
# 3   notice start act different bc peeped something...  normal      5
# 4   Forget unfollowers I believe growing new follo...  normal      3
# 6   Topped group TGP Disc Jam Season Onto HighHors...  normal      3
# 7   That daily baby aspirin heart might preventing...  normal      5

# %%
def basic_clean(text):
  wnl = nltk.stem.WordNetLemmatizer()
  stopwords = nltk.corpus.stopwords.words('english')
  words = re.sub(r'[^\w\s]', '', text).split()
  return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
word = basic_clean(''.join(str(data['text'].tolist())))

# %% [markdown]
# an n-gram is a contiguous sequence of n items from a given sample of text or speech. The items can be phonemes, syllables, letters, words or base pairs according to the application. The n-grams typically are collected from a text or speech corpus. When the items are words, n-grams may also be called shingles

# %%
bigrams_series = (pd.Series(nltk.ngrams(word, 2)).value_counts())[:20]

# %%
bigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(6, 4))
plt.title('20 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('Number of Occurances')
# Out:
# Text(0.5, 0, 'Number of Occurances')

# %%
trigrams_series = (pd.Series(nltk.ngrams(word, 3)).value_counts())[:20]
trigrams_series.sort_values().plot.barh(color='green', width=.9, figsize=(6, 4))
plt.title('20 Most Frequently Occuring Trigrams')
plt.ylabel('Trigram')
plt.xlabel('Number of Occurances')
# Out:
# Text(0.5, 0, 'Number of Occurances')

# %%
#a basic model
x_train, x_test, y_train, y_test = train_test_split(data['text'], data.label,
shuffle=False, test_size=0.2, random_state=2020)

pipe = Pipeline([('vect', CountVectorizer()),
                 ('tfidf', TfidfTransformer()),
                 ('model', LogisticRegression())])

# %%
model = pipe.fit(x_train, y_train)
prediction = model.predict(x_test)
print("accuracy: {}%".format(round(accuracy_score(y_test, prediction)*100,2)))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accuracy: 81.04%

# %%
print(confusion_matrix(y_test, prediction))
# Out:
# [[4889   77  404   58]
#  [ 324  228  417   16]
#  [ 222   23 9763  776]
#  [ 143    4 1327 1329]]

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#      abusive       0.88      0.90      0.89      5428
#      hateful       0.69      0.23      0.35       985
#       normal       0.82      0.91      0.86     10784
#         spam       0.61      0.47      0.53      2803
#
#     accuracy                           0.81     20000
#    macro avg       0.75      0.63      0.66     20000
# weighted avg       0.80      0.81      0.80     20000

# %%
fig, ax = plt.subplots(figsize=(12, 12))
plot_confusion_matrix(model,x_test,y_test, ax=ax)
plt.show()
